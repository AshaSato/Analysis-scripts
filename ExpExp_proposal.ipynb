# %% [markdown]
# # Experience and Expectation in the construal of iconicity in a visual artificial language
#
# Topic of interest is approx "subject-internal factors in perceiving iconicity”

# %%
require(IRdisplay)
setwd("Astra")
# Out:
# Error in setwd("Astra"): cannot change working directory
# Traceback:
#
# 1. setwd("Astra")

# %% [markdown]
# ## Background stuff
#
# Lee & Navarro (2009) presented people with point-patterns based on real constellations and ask them to join up the points such that all are included, but no other restrictions. They found significant inter-participant overlap/agreement in the resulting structures, and signnificant overlap in the structures with a subset of the Delauney triangulation, in particular the minimum spanning tree (MST) (86% overlap). This suggests a bias in connecting point patterns towards producing structures that do so efficiently.

# %%
display_jpeg(file = "img/d_mst.jpg")

# %% [markdown]
# ## Stimuli
#
# ### training stimuli
# Stimuli in the training stages of the experiment differ between conditions only in the assignment of labels to starmaps. Will maybe use the same shuffling procedure as in previous work, i.e. :
#
# Given a set of with 4  congruent (iconic) meaning-label pairs:

# %%
display_jpeg(file = "img/set.jpg")

# %% [markdown]
# An iconic language is created by selecting meaning-label pairs at random:

# %%
display_jpeg(file = "img/iconic.jpg")

# %% [markdown]
# An arbitrary language is created by selecting meanings at random, and pairing them with the labels corresponding to the non-selected meanings (to avoid creating misleading languages):

# %%
display_jpeg(file = "img/arbitrary.jpg")

# %% [markdown]
# ### test stimuli/critical stimuli
#
# The critical stimuli are designed in such a way that iconic interpretation is less accessible than the minimum spanning tree structure. Since the structures people are most likely to perceive on the point patterns have a high degree of overlap with the MST, accessing the iconic representation requires overcoming the bias towards perceiving structure on the MST.
#
# For example:

# %%
display_png(file ="img/crit_mst.jpg")

# %% [markdown]
# People are expected to perceive and produce (when asked to connect the dots) structures with a high degree of overlap with the minimum spanning tree above. When I informally asked a bunch of people to connect the dots in the image above, this is what they did (on their phones, etc):

# %%
display_png(file = "img/attempts.jpg")

# %% [markdown]
# There is a possible way of perceiving/ connecting the dots to form the image of a hand (below), with a low degree of overlap with the MST. We predict that people in the iconic condition who have been trained on an iconic language will be more likely to deviate from the MST in order to produce something like this:

# %%
display_png(file = "img/mst_hand_overlap.png", width = 500)

# %% [markdown]
# ## Procedure
#
# ### Pre-experiment:
#
# I would like to gather some sort of creativity metric, as I'm guessing some portion of iconicity perceived in the random pairings will be predicted from individual differences in creativity.
#
#
# ### Training
#
# Training is identical in both conditions: Participants see a star map without a label, are asked to guess the meaning (forward guessing to improve recall), and are then given the correct target label. The only difference between conditions are the correspondence between starmaps and labels (as described above).
# ### Testing
#
# #### guessing task
# Participants see a star map and are asked to guess its label (free guess? or pick from an array?).
#
# Prediction: people will be better at guessing in the iconic condition.
#
# #### connecting task
#
# Participants are asked to connect the points. I think it's important that this is done before giving them the meaning?
#
# Prediction: The structures produced by participants in the iconic condition will show greater deviation from the MST structures.
#
# #### rating task
# Participants are given the target label (thereby receiving feedback on their guess) and are asked to give an iconicity rating, e.g. "How much do you think this looks like a _____".
#
# Prediction: Tentatively, predict higher ratings in the iconic condition. But on the other hand, those who have been trained on iconic pairs might expect even more obvious connections, whilst those in the arbitrary condition, once they have been given the meaning, might give higher ratings as the iconicity exceeds what they were expecting. Now that I think about it I'm not sure what a rating task is going to tell us.
